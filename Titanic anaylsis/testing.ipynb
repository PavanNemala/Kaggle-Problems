# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
train = pd.read_csv("train.csv")
test = pd.read_csv("test.csv")

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
train["Embarked"].value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
train.describe(include="all")
# Out:
#         PassengerId    Survived      Pclass                      Name   Sex  \
# count    891.000000  891.000000  891.000000                       891   891
# unique          NaN         NaN         NaN                       891     2
# top             NaN         NaN         NaN  Bystrom, Mrs. (Karolina)  male
# freq            NaN         NaN         NaN                         1   577
# mean     446.000000    0.383838    2.308642                       NaN   NaN
# std      257.353842    0.486592    0.836071                       NaN   NaN
# min        1.000000    0.000000    1.000000                       NaN   NaN
# 25%      223.500000    0.000000    2.000000                       NaN   NaN
# 50%      446.000000    0.000000    3.000000                       NaN   NaN
# 75%      668.500000    1.000000    3.000000                       NaN   NaN
# max      891.000000    1.000000    3.000000                       NaN   NaN
#
# ...

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
e = train.copy()

# %%
e.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
e["Embarked"].fillna(e["Embarked"].mode()[0],inplace=True)

# %%
e["Embarked"].value_counts()
# Out:
# S    646
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
train["Embarked"].fillna(e["Embarked"].mode()[0],inplace=True)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       891 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
e["Age"].median()
# Out:
# 28.0

# %%
e.Age.plot(kind="box")

# %%
e['Age'].fillna(e["Age"].median(),inplace=True)

# %%
e.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            891 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       891 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
train['Age'].fillna(train["Age"].median(),inplace=True)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            891 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       891 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
e.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male  28.0      0
# ...

# %%
e["Name"].head(10)
# Out:
# 0                              Braund, Mr. Owen Harris
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                               Heikkinen, Miss. Laina
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                             Allen, Mr. William Henry
# 5                                     Moran, Mr. James
# 6                              McCarthy, Mr. Timothy J
# 7                       Palsson, Master. Gosta Leonard
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9                  Nasser, Mrs. Nicholas (Adele Achem)
# Name: Name, dtype: object

# %%
e.drop(columns=['Cabin'],inplace=True)

# %%
e.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 11 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            891 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Embarked       891 non-null object
# dtypes: float64(2), int64(5), object(4)
# memory usage: 76.7+ KB

# %%
e["family"] = e["SibSp"] + e["Parch"]
e.drop(columns=['SibSp','Parch'],inplace=True)

# %%
train["family"] = train["SibSp"] + train["Parch"]

# %%
train.drop(columns=['SibSp','Parch'],inplace=True)

# %%
e.drop(columns="Name",inplace=True)

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  \
# 0                            Braund, Mr. Owen Harris    male  22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                             Heikkinen, Miss. Laina  female  26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                           Allen, Mr. William Henry    male  35.0
#
#              Ticket     Fare Cabin Embarked  family
# 0         A/5 21171   7.2500   NaN        S       1
# 1          PC 17599  71.2833   C85        C       1
# 2  STON/O2. 3101282   7.9250   NaN        S       0
# 3            113803  53.1000  C123        S       1
# 4            373450   8.0500   NaN        S       0

# %%
train.drop(columns=["Name"],inplace=True)

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass     Sex   Age Embarked  family
# 0            1         0       3    male  22.0        S       1
# 1            2         1       1  female  38.0        C       1
# 2            3         1       3  female  26.0        S       0
# 3            4         1       1  female  35.0        S       1
# 4            5         0       3    male  35.0        S       0

# %%
pd.get_dummies(train,drop_first=True)
# Out:
#      PassengerId  Survived  Pclass   Age  family  Sex_male  Embarked_Q  \
# 0              1         0       3  22.0       1         1           0
# 1              2         1       1  38.0       1         0           0
# 2              3         1       3  26.0       0         0           0
# 3              4         1       1  35.0       1         0           0
# 4              5         0       3  35.0       0         1           0
# ..           ...       ...     ...   ...     ...       ...         ...
# 886          887         0       2  27.0       0         1           0
# 887          888         1       1  19.0       0         0           0
# 888          889         0       3  28.0       3         0           0
# 889          890         1       1  26.0       0         1           0
# 890          891         0       3  32.0       0         1           1
#
#      Embarked_S
# 0             1
# 1             0
# 2             1
# 3             1
# 4             1
# ...

# %%
p = pd.get_dummies(train)

# %%
p.head()
# Out:
#    PassengerId  Survived  Pclass   Age  family  Sex_female  Sex_male  \
# 0            1         0       3  22.0       1           0         1
# 1            2         1       1  38.0       1           1         0
# 2            3         1       3  26.0       0           1         0
# 3            4         1       1  35.0       1           1         0
# 4            5         0       3  35.0       0           0         1
#
#    Embarked_C  Embarked_Q  Embarked_S
# 0           0           0           1
# 1           1           0           0
# 2           0           0           1
# 3           0           0           1
# 4           0           0           1

# %%
from sklearn.model_selection import train_test_split,GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier,AdaBoostClassifier,GradientBoostingClassifier
from sklearn.metrics import accuracy_score, f1_score, roc_curve, roc_auc_score, confusion_matrix
from sklearn.preprocessing import StandardScaler

# %%
# Split the training data by the conventional 80-20 split
X = p.drop(columns=['Survived'])
Y = p['Survived'].values
trainx, testx, trainy, testy = train_test_split(X,Y,test_size=0.2)

# %%
# Creating the model
logr = LogisticRegression(penalty='l2',C=1.0,solver='lbfgs')
logr.fit(trainx,trainy)
# Out:
# c:\users\pavankumar.nemala\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
# PassengerId    418 non-null int64
# Pclass         418 non-null int64
# Name           418 non-null object
# Sex            418 non-null object
# Age            332 non-null float64
# SibSp          418 non-null int64
# Parch          418 non-null int64
# Ticket         418 non-null object
# Fare           417 non-null float64
# Cabin          91 non-null object
# Embarked       418 non-null object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 36.0+ KB

# %%
test = pd.read_csv("test.csv")
test["Embarked"].fillna(test["Embarked"].mode()[0],inplace=True)
test['Age'].fillna(test["Age"].median(),inplace=True)
test.drop(columns=["Cabin","Name","Ticket"],inplace=True)

# %%
test["Fare"].fillna(test["Fare"].mode()[0],inplace=True)

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 8 columns):
# PassengerId    418 non-null int64
# Pclass         418 non-null int64
# Sex            418 non-null object
# Age            418 non-null float64
# SibSp          418 non-null int64
# Parch          418 non-null int64
# Fare           418 non-null float64
# Embarked       418 non-null object
# dtypes: float64(2), int64(4), object(2)
# memory usage: 26.2+ KB

# %%
test["family"] = test["SibSp"] + test["Parch"]
test.drop(columns=["SibSp","Parch"],inplace=True)
test1 = pd.get_dummies(test)
test1
# Out:
#      PassengerId  Pclass   Age      Fare  family  Sex_female  Sex_male  \
# 0            892       3  34.5    7.8292       0           0         1
# 1            893       3  47.0    7.0000       1           1         0
# 2            894       2  62.0    9.6875       0           0         1
# 3            895       3  27.0    8.6625       0           0         1
# 4            896       3  22.0   12.2875       2           1         0
# ..           ...     ...   ...       ...     ...         ...       ...
# 413         1305       3  27.0    8.0500       0           0         1
# 414         1306       1  39.0  108.9000       0           1         0
# 415         1307       3  38.5    7.2500       0           0         1
# 416         1308       3  27.0    8.0500       0           0         1
# 417         1309       3  27.0   22.3583       2           0         1
#
#      Embarked_C  Embarked_Q  Embarked_S
# 0             0           1           0
# ...

# %%
test1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 10 columns):
# PassengerId    418 non-null int64
# Pclass         418 non-null int64
# Age            418 non-null float64
# Fare           418 non-null float64
# family         418 non-null int64
# Sex_female     418 non-null uint8
# Sex_male       418 non-null uint8
# Embarked_C     418 non-null uint8
# Embarked_Q     418 non-null uint8
# Embarked_S     418 non-null uint8
# dtypes: float64(2), int64(3), uint8(5)
# memory usage: 18.5 KB

# %%
op1 = logr.predict(test1.drop(columns=['PassengerId'],axis=1))
opf_df1 = pd.DataFrame({'PassengerId': test1.PassengerId, 'Survived': op1})
opf_df1.to_csv('final.csv', index=False)

# %%
result = pd.read_csv("final.csv")

# %%
result
# Out:
#      PassengerId  Survived
# 0            892         0
# 1            893         0
# 2            894         0
# 3            895         0
# 4            896         0
# ..           ...       ...
# 413         1305         0
# 414         1306         0
# 415         1307         0
# 416         1308         0
# 417         1309         0
#
# [418 rows x 2 columns]
