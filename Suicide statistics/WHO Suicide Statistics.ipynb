# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("who_suicide_statistics.csv")
data.head()
# Out:
#    country  year     sex          age  suicides_no  population
# 0  Albania  1985  female  15-24 years          NaN    277900.0
# 1  Albania  1985  female  25-34 years          NaN    246800.0
# 2  Albania  1985  female  35-54 years          NaN    267500.0
# 3  Albania  1985  female   5-14 years          NaN    298300.0
# 4  Albania  1985  female  55-74 years          NaN    138700.0

# %%
male_suicide  = data
female_suicide = data
data.head(100)
# Out:
#     country  year     sex          age  suicides_no  population
# 0   Albania  1985  female  15-24 years          NaN    277900.0
# 1   Albania  1985  female  25-34 years          NaN    246800.0
# 2   Albania  1985  female  35-54 years          NaN    267500.0
# 3   Albania  1985  female   5-14 years          NaN    298300.0
# 4   Albania  1985  female  55-74 years          NaN    138700.0
# 5   Albania  1985  female    75+ years          NaN     34200.0
# 6   Albania  1985    male  15-24 years          NaN    301400.0
# 7   Albania  1985    male  25-34 years          NaN    264200.0
# 8   Albania  1985    male  35-54 years          NaN    296700.0
# 9   Albania  1985    male   5-14 years          NaN    325800.0
# 10  Albania  1985    male  55-74 years          NaN    132500.0
# 11  Albania  1985    male    75+ years          NaN     21100.0
# 12  Albania  1986  female  15-24 years          NaN    283900.0
# 13  Albania  1986  female  25-34 years          NaN    252100.0
# ...

# %%
female_suicide[female_suicide['suicides_no'] == 150]
# Out:
#                                   country  year     sex          age  \
# 1418                            Argentina  2009  female  35-54 years
# 1428                            Argentina  2010  female  15-24 years
# 2738                              Austria  1990  female  35-54 years
# 2742                              Austria  1990    male  15-24 years
# 7960                               Canada  2002  female  55-74 years
# 8528                                Chile  1983    male  35-54 years
# 8647                                Chile  1993    male  25-34 years
# 8846                                Chile  2010  female  35-54 years
# 10826                      Czech Republic  1990  female  35-54 years
# 10883                      Czech Republic  1994    male    75+ years
# 10888                      Czech Republic  1995  female  55-74 years
# 11504                             Denmark  2008    male  35-54 years
# 12751                             Ecuador  2005    male  25-34 years
# ...

# %%
male_suicide.groupby(['country'], sort=False)['suicides_no'].max()
# Out:
# country
# Albania                                  39.0
# Anguilla                                  1.0
# Antigua and Barbuda                       2.0
# Argentina                               745.0
# Armenia                                  32.0
# Aruba                                     4.0
# Australia                               944.0
# Austria                                 540.0
# Azerbaijan                               79.0
# Bahamas                                   5.0
# Bahrain                                  21.0
# Barbados                                  7.0
# Belarus                                1391.0
# Belgium                                 686.0
# Belize                                    9.0
# Bermuda                                   4.0
# Bolivia                                   5.0
# Bosnia and Herzegovina                  151.0
# Brazil                                 3238.0
# British Virgin Islands                    1.0
# ...

# %%
female_suicide.groupby(['country'])['suicides_no'].max()
# Out:
# country
# Albania                                  39.0
# Anguilla                                  1.0
# Antigua and Barbuda                       2.0
# Argentina                               745.0
# Armenia                                  32.0
# Aruba                                     4.0
# Australia                               944.0
# Austria                                 540.0
# Azerbaijan                               79.0
# Bahamas                                   5.0
# Bahrain                                  21.0
# Barbados                                  7.0
# Belarus                                1391.0
# Belgium                                 686.0
# Belize                                    9.0
# Bermuda                                   4.0
# Bolivia                                   5.0
# Bosnia and Herzegovina                  151.0
# Brazil                                 3238.0
# British Virgin Islands                    1.0
# ...
